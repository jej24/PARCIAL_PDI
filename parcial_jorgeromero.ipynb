# %% [markdown]
# <a href="https://colab.research.google.com/github/jej24/PARCIAL_PDI/blob/master/parcial_jorgeromero.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path ='/content/drive/My Drive/PDI/IMAGENPARCIAL/'

os.chdir(path)

# !pwd

# %matplotlib inline
# Out:
# /content/drive/My Drive/PDI/IMAGENPARCIAL

# %%
def displayGray2(a,b,title1 = "Original", title2 = "Edited"):
  plt.figure(figsize=(10,10))
  plt.subplot(121),plt.imshow(a,cmap='gray'), plt.title(title1)
  plt.xticks([]),plt.yticks([])
  plt.sublot(122), plt.imshow(b, cmap='gray'), plt.title(title2)
  plt.xticks([]), plt.yticks([])
  plt.show()

# %%
img = cv2.imread("frijol.jpg",0)
row, colum =img.shape
img2 = cv2.imread("frijol.jpg", cv2.IMREAD_GRAYSCALE)
displayGray2(img, img2)
img1 = np.zeros((rows, columns), dtype=np.uint8)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-7cb2edf2551c> in <module>()
#       2 row, colum =img.shape
#       3 img2 = cv2.imread("frijol.jpg", cv2.IMREAD_GRAYSCALE)
# ----> 4 displayGray2(img, img2)
#       5 img1 = np.zeros((rows, columns), dtype=np.uint8)
#
# <ipython-input-14-d4e122d0cb53> in displayGray2(a, b, title1, title2)
#       3   plt.subplot(121),plt.imshow(a,cmap='gray'), plt.title(title1)
#       4   plt.xticks([]),plt.yticks([])
# ----> 5   plt.sublot(122), plt.imshow(b, cmap='gray'), plt.title(title2)
#       6   plt.xticks([]), plt.yticks([])
#       7   plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'sublot'

# %%
import numpy as np
import cv2
img = cv2.imread("cara.jpg", cv2.IMREAD_GRAYSCALE)

#x= np.array(255*(img/255)*2*gamma, dtype='uint')
For i in range(x= np.array(255*(img/255)*2*gamma, dtype='uint'))


displayGray2(img)
# Out:
#   File "<ipython-input-41-0a69080be567>", line 6
#     For i in range(x= np.array(255*(img/255)*2*gamma, dtype='uint'))
#         ^
# SyntaxError: invalid syntax

# %%
img = cv2.imread("cafe.jpg", cv2.IMREAD_GRAYSCALE)
rows, columns = img.shape
img2 = np.zeros((rows, columns), dtype=np.uint8)

# %%
img_BGR=cv2.imread('ruby.jpg',cv2.IMREAD_COLOR)

# %%
img_RGB=cv2.cvtColor(img_BGR,cv2.COLOR_BGR2RGB)
r,g,b = cv2.split(img_RGB)

display4(img_RGB,r,g,b,"RGB","r","g","b")

# %%
count = 2
plt.figure(figsize=(12,4))
plt.subplot(1,4,1), plt.imshow(img_RGB/255.0), plt.title("original RGB")    
plt.axis("off")
for i, lab in enumerate(["R","G","B"]):
    crgb = np.zeros(img_RGB.shape)
    crgb[:,:,i] = img_RGB[:,:,i]
    plt.subplot(1,4,count), plt.imshow(crgb/255.0), plt.title(lab) 
    plt.axis("off")
    count += 1
    
plt.show()

# %%
img_LAB=cv2.cvtColor(img_BGR, cv2.COLOR_BGR2LAB);
L,A,B = cv2.split(img_LAB)
display4(img_LAB,L,A,B,"LAB","L","A","B")
